# %%
import yaml
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import IPython
notebook_name = "/".join(
        IPython.extract_module_locals()[1]["__vsc_ipynb_file__"].split("/")[-5:]
    )
print(notebook_name)
# Out:
# utah/research/USOS_shared/Plotting/yaml_plot_test.ipynb

# %%
data_date = '8_6_2024'
yaml_usos_dirpath = '../F0AM-4.3.0.1/Campaign_Data/obs_yaml/parked/'
yaml_usos_full_filepath = yaml_usos_dirpath + 'USOS_' + data_date + '.yaml'

run_number = '26'
yaml_run_dirpath = '../F0AM-4.3.0.1/Runs/USOS_' + data_date + '/Run' + run_number + '/'
yaml_run_full_filepath = yaml_run_dirpath + data_date + '_run.yaml'

# %%
with open(yaml_usos_full_filepath, 'r') as f:
    yaml_usos = yaml.full_load(f)
#print(yaml_usos)

with open(yaml_run_full_filepath, 'r') as f:
    yaml_run = yaml.full_load(f)
#print(yaml_run)

# %%
list(yaml_run.keys())
# Out:
# ['BkgdConc',
#  'Chem',
#  'Cnames',
#  'Conc',
#  'InitConc',
#  'Met',
#  'ModelOptions',
#  'SolarParam',
#  'StepIndex',
#  'Time',
#  'iRO2']

# %%
list(yaml_usos.keys())
# Out:
# ['AOD',
#  'APAN_CIMS',
#  'Acetaldehyde_PTR',
#  'Acetone_Propanal_PTR',
#  'Acetone_WAS',
#  'Acetonitrile_PTR',
#  'Acrolein_PTR',
#  'Acrolein_WAS',
#  'Aerosol_conc_POPS',
#  'Alpha_Pinene_WAS',
#  'Altitude_m',
#  'Benzaldehyde_PTR',
#  'Benzene_PTR',
#  'Benzene_WAS',
#  'Beta_Pinene_WAS',
#  'Br2_CIMS',
#  'BrCl_CIMS',
#  'BrO_CIMS',
#  'C10H17NO4_CIMS',
#  'C2Cl4_WAS',
#  'C2HCl3_WAS',
#  'C4H7NO5_CIMS',
#  'C5H10O3_CIMS',
#  'C5H9NO5_CIMS',
#  'C7H4ClF3_PTR',
#  'C8Aromatics_PTR',
#  'C9Aromatics_PTR',
#  'CCl4_WAS',
#  'CF2Cl2_WAS',
#  'CFCl3_WAS',
#  'CH2Cl2_WAS',
#  'CH3Br_WAS',
#  'CH4_CRDS',
#  'CH4_Piccaro',
#  'CO2_Piccaro',
#  'CO_Piccaro',
#  'Cl2_CIMS',
#  'ClNO2_CIMS',
#  'Course_deg',
#  'CycloPentane_WAS',
#  'D5_siloxane_PTR',
#  'DMS_PTR',
#  'Effective_radius_POPS',
#  'Ethane_WAS',
#  'Ethanol_PTR',
#  'Ethene_WAS',
#  'Ethyl_WAS',
#  'Ethyne_WAS',
#  'Extinction_POPS',
#  'File_Index',
#  'Furan_WAS',
#  'GndSpd_ms',
#  'H2O_CRDS',
#  'H2O_Piccaro',
#  'HCHO_CRDS',
#  'HCOOH_CIMS',
#  'HNO3_CIMS',
#  'HONO_CIMS',
#  'Heading_deg',
#  'ISOPN_CIMS',
#  'Isoprene_PTR',
#  'Isoprene_WAS',
#  'Lat',
#  'Limonene_WAS',
#  'Lon',
#  'MACR_WAS',
#  'MVK_MACR_PTR',
#  'Methanethiol_PTR',
#  'Methanol_PTR',
#  'MethylCycloHexane_WAS',
#  'MethylCycloPentane_WAS',
#  'Monoterpenes_PTR',
#  'N2O5_CIMS',
#  'NCl3_CIMS',
#  'NO2_LIF',
#  'NO_LIF',
#  'NOy_LIF',
#  'Naphthalene_PTR',
#  'Nonanal_PTR',
#  'O3_ppbv',
#  'Octanal_PTR',
#  'PAN_CIMS',
#  'PPN_CIMS',
#  'Particle_conc_bin01_POPS',
#  'Particle_conc_bin02_POPS',
#  'Particle_conc_bin03_POPS',
#  'Particle_conc_bin04_POPS',
#  'Particle_conc_bin05_POPS',
#  'Particle_conc_bin06_POPS',
#  'Particle_conc_bin07_POPS',
#  'Particle_conc_bin08_POPS',
#  'Particle_conc_bin09_POPS',
#  'Particle_conc_bin10_POPS',
#  'Particle_conc_bin11_POPS',
#  'Particle_conc_bin12_POPS',
#  'Particle_conc_bin13_POPS',
#  'Particle_conc_bin14_POPS',
#  'Particle_conc_bin15_POPS',
#  'Particle_conc_bin16_POPS',
#  'Particle_conc_bin17_POPS',
#  'Particle_conc_bin18_POPS',
#  'Particle_conc_bin19_POPS',
#  'Particle_conc_bin20_POPS',
#  'Particle_conc_bin21_POPS',
#  'Particle_conc_bin22_POPS',
#  'Particle_conc_bin23_POPS',
#  'Particle_conc_bin24_POPS',
#  'Particle_conc_bin25_POPS',
#  'Particle_conc_bin26_POPS',
#  'Particle_conc_bin27_POPS',
#  'Particle_conc_bin28_POPS',
#  'Particle_conc_bin29_POPS',
#  'Particle_conc_bin30_POPS',
#  'Particle_conc_bin31_POPS',
#  'Particle_conc_bin32_POPS',
#  'Particle_conc_bin33_POPS',
#  'Particle_conc_bin34_POPS',
#  'Particle_conc_bin35_POPS',
#  'Particle_conc_bin36_POPS',
#  'Press_mb_POPS',
#  'Pressure_mb',
#  'Propane_WAS',
#  'Propene_WAS',
#  'RH_percent',
#  'Styrene_PTR',
#  'Surface_area_conc_POPS',
#  'Temp_C_POPS',
#  'Temp_K',
#  'Time_Start_POPS',
#  'Time_Stop_POPS',
#  'Toluene_PTR',
#  'Toluene_WAS',
#  'Volume_density_POPS',
#  'WindDir_deg',
#  'WindSpd_ms',
#  'c2Butene_WAS',
#  'c2Pentene_WAS',
#  'iButane_WAS',
#  'iPentane_WAS',
#  'iPropylBenzene_WAS',
#  'iPropylONO2_WAS',
#  'jBr2',
#  'jBrCl',
#  'jCCl4',
#  'jCH2Oa',
#  'jCH2Ob',
#  'jCl2',
#  'jClNO2',
#  'jClOa',
#  'jClOb',
#  'jHNO2',
#  'jHNO3',
#  'jI2',
#  'jN2O5',
#  'jNO2',
#  'jNO2_meas',
#  'jNO2_ratio',
#  'jNO3a',
#  'jNO3b',
#  'jO3',
#  'm_p_Xylene_WAS',
#  'nButane_WAS',
#  'nDecane_WAS',
#  'nHeptane_WAS',
#  'nHexane_WAS',
#  'nNonane_WAS',
#  'nOctane_WAS',
#  'nPentane_WAS',
#  'nPropylBenzene_WAS',
#  'nPropylONO2_WAS',
#  'o_Xylene_WAS',
#  't2Butene_WAS',
#  't2Pentene_WAS',
#  'time_MST',
#  'time_UTC',
#  'time_local',
#  'x123_TriMethylBenzene_WAS',
#  'x124_TriMethylBenzene_WAS',
#  'x135_TriMethylBenzene_WAS',
#  'x13_Butadiene_WAS',
#  'x1_Butene_WAS',
#  'x1_Pentene_WAS',
#  'x224_TriMethylPentane_WAS',
#  'x22_DiMethylButane_WAS',
#  'x2_EthylToluene_WAS',
#  'x2_MethylPentane_WAS',
#  'x3_MethylPentane_WAS',
#  'x3_x4_EthylToluene_WAS',
#  'timehr_output']

# %%
yaml_run['Chem']['f']
print(len(yaml_run['Chem']['f']))
# Out:
# 329

# %%
fig, ax = plt.subplots(figsize = (20,10))
hour_range = np.arange(0,24,0.5)
plt.plot(hour_range, yaml_usos['O3_ppbv'], label = 'Obs', linestyle = 'solid', color = 'black')
plt.plot(hour_range, yaml_run['Conc']['O3'], label = 'Model', linestyle = 'dashed', color = 'red')
plt.xlabel('Hour (Mountain)')
plt.xticks(np.arange(0,24))
plt.margins(x=0)

plt.ylabel('Ozone Concentration (ppb)')

plt.legend()
plt.title('Comparison of Ozone between Model and Observations for Run 26')
# Out:
# Text(0.5, 1.0, 'Comparison of Ozone between Model and Observations for Run 26')

# %%
def plot_species(species_name):


plot_species(species_name = 'O3')

# %%
fig, ax = plt.subplots(figsize = (20,10))
hour_range = np.arange(0,24,0.5)

day4_idx = model_conc_load
model_ozone = day4_idx['O3']
obs_ozone = obs_conc_load['O3_ppbv']

plt.plot(hour_range,model_ozone, label = 'Model', linestyle = 'dashed', color = 'red')
plt.plot(hour_range,obs_ozone, label = 'Obs', linestyle = 'solid', color = 'black')
plt.xlabel('Hour')
plt.xticks(np.arange(0,24))
plt.ylabel('Ozone Concentration (ppb)')
plt.title('Comparison of Ozone between Day 4 of Model Run and Observations for Run'+str(run_number))

plt.legend()
plt.savefig(run_path_plots +  'ozone_compare_model_and_obs.png')
plt.show()
