# %%
from Dog import Dog

# %%
fido = Dog(name='Fido', color='white', breed='Maltese')
fido.write_name_into_plot()
fido.write_breed_into_plot()

# %%
buster = Dog(name='Buster', color='white', breed='Maltese')
buster.write_breed_into_plot()

# %%
fido.write_name_into_plot('fido.png')

# %%
buster.write_name_into_plot('buster.png')
